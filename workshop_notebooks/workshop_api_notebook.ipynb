# %% [markdown]
# ## APIs

# %% [markdown]
# Let's start by looking at [OMDb API](https://www.omdbapi.com/).
#
# The OMDb API is a free web service to obtain movie information, all content and images on the site are contributed and maintained by our users.
#
# The Python package [urllib](https://docs.python.org/3/howto/urllib2.html) can be used to fetch resources from the internet.
#
# OMDb tells us what kinds of requests we can make. We are going to do a title search. As you can see below, we have an additional parameter "&Season=1" which does not appear in the parameter tables. If you read through the change log, you will see it documented there.
#
# Using the urllib and json packages allow us to call an API and store the results locally.

# %%
import json
import urllib.request

# %%
data = json.loads(urllib.request.urlopen('http://www.omdbapi.com/?t=Game%20of%20Thrones&Season=1').read().\
                  decode('utf8'))

# %% [markdown]
# What should we expect the type to be for the variable data?

# %%
print(type(data))
# Out:
# <class 'dict'>

# %% [markdown]
# What do you think the data will look like?

# %%
data
# Out:
# {'Episodes': [{'Episode': '1',
#    'Released': '2011-04-17',
#    'Title': 'Winter Is Coming',
#    'imdbID': 'tt1480055',
#    'imdbRating': '8.9'},
#   {'Episode': '2',
#    'Released': '2011-04-24',
#    'Title': 'The Kingsroad',
#    'imdbID': 'tt1668746',
#    'imdbRating': '8.7'},
#   {'Episode': '3',
#    'Released': '2011-05-01',
#    'Title': 'Lord Snow',
#    'imdbID': 'tt1829962',
#    'imdbRating': '8.6'},
#   {'Episode': '4',
#    'Released': '2011-05-08',
#    'Title': 'Cripples, Bastards, and Broken Things',
#    'imdbID': 'tt1829963',
#    'imdbRating': '8.7'},
#   {'Episode': '5',
#    'Released': '2011-05-15',
#    'Title': 'The Wolf and the Lion',
#    'imdbID': 'tt1829964',
#    'imdbRating': '9.0'},
#   {'Episode': '6',
#    'Released': '2011-05-22',
#    'Title': 'A Golden Crown',
#    'imdbID': 'tt1837862',
#    'imdbRating': '9.1'},
#   {'Episode': '7',
#    'Released': '2011-05-29',
#    'Title': 'You Win or You Die',
#    'imdbID': 'tt1837863',
#    'imdbRating': '9.2'},
#   {'Episode': '8',
#    'Released': '2011-06-05',
#    'Title': 'The Pointy End',
#    'imdbID': 'tt1837864',
#    'imdbRating': '9.0'},
#   {'Episode': '9',
#    'Released': '2011-06-12',
#    'Title': 'Baelor',
#    'imdbID': 'tt1851398',
#    'imdbRating': '9.5'},
#   {'Episode': '10',
#    'Released': '2011-06-19',
#    'Title': 'Fire and Blood',
#    'imdbID': 'tt1851397',
#    'imdbRating': '9.4'}],
#  'Response': 'True',
#  'Season': '1',
#  'Title': 'Game of Thrones',
#  'totalSeasons': '8'}

# %% [markdown]
# We know have a dictionary object of our data. We can use python to manipulate it in a variety of ways. For example, we can print all the titles of the episodes.

# %%
for episode in data['Episodes']:
  print(episode['Title'], episode['imdbRating'])
# Out:
# Winter Is Coming 8.9
# The Kingsroad 8.7
# Lord Snow 8.6
# Cripples, Bastards, and Broken Things 8.7
# The Wolf and the Lion 9.0
# A Golden Crown 9.1
# You Win or You Die 9.2
# The Pointy End 9.0
# Baelor 9.5
# Fire and Blood 9.4

# %% [markdown]
# We can use pandas to convert the episode information to a dataframe.

# %%
import pandas as pd

df = pd.DataFrame.from_dict(data['Episodes'])

# %%
df
# Out:
#   Episode    Released                                  Title     imdbID  \
# 0       1  2011-04-17                       Winter Is Coming  tt1480055
# 1       2  2011-04-24                          The Kingsroad  tt1668746
# 2       3  2011-05-01                              Lord Snow  tt1829962
# 3       4  2011-05-08  Cripples, Bastards, and Broken Things  tt1829963
# 4       5  2011-05-15                  The Wolf and the Lion  tt1829964
# 5       6  2011-05-22                         A Golden Crown  tt1837862
# 6       7  2011-05-29                     You Win or You Die  tt1837863
# 7       8  2011-06-05                         The Pointy End  tt1837864
# 8       9  2011-06-12                                 Baelor  tt1851398
# 9      10  2011-06-19                         Fire and Blood  tt1851397
#
#   imdbRating
# 0        8.9
# 1        8.7
# 2        8.6
# 3        8.7
# 4        9.0
# 5        9.1
# 6        9.2
# 7        9.0
# 8        9.5
# 9        9.4

# %% [markdown]
# And, we can save our data locally to use later.

# %%
with open('omdb_api_data.json', 'w') as f:
    json.dump(data, f)

# %% [markdown]
# Let's try an API that requires an API key!
#
# "The [Digital Public Library of America](https://dp.la/) brings together the riches of America’s libraries, archives, and museums, and makes them freely available to the world. It strives to contain the full breadth of human expression, from the written word, to works of art and culture, to records of America’s heritage, to the efforts and data of science."
#
# And, they have an [API](https://dp.la/info/developers/codex/api-basics/).
#
# In order to use the API, you need to [request a key](https://dp.la/info/developers/codex/policies/#get-a-key). You can do this with an HTTP POST request.
#
# If you are using OS X or Linux, replace "YOUR_EMAIL@example.com" in the cell below with your email address and execute the cell. This will send the rquest to DPLA and they will email your API key to the email address you provided. To successfully query the API, you must include the ?api_key= parameter with the 32-character hash following.

# %%
# execute this on OS X or Linux
! curl -v -XPOST http://api.dp.la/v2/api_key/nicole@nicoledonnelly.me
# Out:
# *   Trying 52.21.85.131...
# * Connected to api.dp.la (52.21.85.131) port 80 (#0)
# > POST /v2/api_key/nicole@nicoledonnelly.me HTTP/1.1
# > Host: api.dp.la
# > User-Agent: curl/7.43.0
# > Accept: */*
# >
# < HTTP/1.1 201 Created
# < Access-Control-Allow-Origin: *
# < Cache-Control: max-age=0, private, must-revalidate
# < Content-Type: application/json; charset=utf-8
# < Date: Sat, 22 Oct 2016 18:28:47 GMT
# < ETag: "8b66d9fe7ded79e3151d5a22f0580d99"
# < Server: nginx/1.1.19
# < Status: 201 Created
# < X-Request-Id: d14dfbdc08191f8e0e74286d2fd375a8
# < X-Runtime: 0.195748
# < X-UA-Compatible: IE=Edge,chrome=1
# < Content-Length: 89
# < Connection: keep-alive
# <
# * Connection #0 to host api.dp.la left intact
# {"message":"API key created and sent via email. Be sure to check your Spam folder, too."}

# %% [markdown]
# If you are on Windows 7 or 10, [open PowerShell](http://www.tenforums.com/tutorials/25581-windows-powershell-open-windows-10-a.html). Replace "YOUR_EMAIL@example.com" in the cell below with your email address. Copy the code and paste it at the command prompt in PowerShell. This will send the rquest to DPLA and they will email your API key to the email address you provided. To successfully query the API, you must include the ?api_key= parameter with the 32-character hash following.

# %%
#execute this on Windows
Invoke-WebRequest -Uri ("http://api.dp.la/v2/api_key/YOUR_EMAIL@example.com") -Method POST -Verbose -usebasicparsing

# %% [markdown]
# You will get a response similar to what is shown below and will receive an email fairly quickly from DPLA with your key.

# %% [markdown]
#     shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
#     *   Trying 52.2.169.251...
#     * Connected to api.dp.la (52.2.169.251) port 80 (#0)
#     > POST /v2/api_key/YOUR_EMAIL@example.com HTTP/1.1
#     > Host: api.dp.la
#     > User-Agent: curl/7.43.0
#     > Accept: */*
#     >
#     < HTTP/1.1 201 Created
#     < Access-Control-Allow-Origin: *
#     < Cache-Control: max-age=0, private, must-revalidate
#     < Content-Type: application/json; charset=utf-8
#     < Date: Thu, 20 Oct 2016 20:53:24 GMT
#     < ETag: "8b66d9fe7ded79e3151d5a22f0580d99"
#     < Server: nginx/1.1.19
#     < Status: 201 Created
#     < X-Request-Id: d61618751a376452ac3540b3157dcf48
#     < X-Runtime: 0.179920
#     < X-UA-Compatible: IE=Edge,chrome=1
#     < Content-Length: 89
#     < Connection: keep-alive
#     <
#     * Connection #0 to host api.dp.la left intact
#     {"message":"API key created and sent via email. Be sure to check your Spam folder, too."}

# %% [markdown]
# It is good practice not to put your keys in your code. You should store them in a file and read them in from there. If you are pushing your code to GitHub, make sure you put your key files in .gitignore.
#
# I created a file on my drive called "dpla_config_secret.json". The contents of the file look like this:
#
# {
# 	"api_key" : "my api key here"
# }
#
# I can then write code to read the information in.

# %%
with open("./api/dpla_config_secret.json") as key_file:
    key = json.load(key_file)

# %%
key
# Out:
# {'api_key': '22443a3c90575f968c9be540e42d5e81'}

# %% [markdown]
# Then, when I create my API query, I can use a variable in place of my actual key.
#
# The Requests library allows us to build urls with different parameters. You build the parameters as a dictionary that contains key/value pairs for everything after the '?' in your url.

# %%
import requests

# %%
# we are specifying our url and parameters here as variables
url = 'http://api.dp.la/v2/items/'
params = {'api_key' : key['api_key'], 'q' : 'goats+AND+cats'}

# %%
# we are creating a response object, r
r = requests.get(url, params=params)

# %%
type(r)
# Out:
# requests.models.Response

# %%
# we can look at the url that was created by requests with our specified variables
r.url
# Out:
# 'http://api.dp.la/v2/items/?api_key=22443a3c90575f968c9be540e42d5e81&q=goats%2BAND%2Bcats'

# %%
# we can check the status code of our request
r.status_code
# Out:
# 200

# %% [markdown]
# [HTTP Status Codes](http://www.restapitutorial.com/httpstatuscodes.html)

# %%
# we can look at the content of our request
print(r.content)
# Out:
# b'{"count":29,"start":0,"limit":10,"docs":[{"@context":"http://dp.la/api/items/context","isShownAt":"http://catalog.hathitrust.org/Record/009232885","dataProvider":["Cornell University"],"@type":"ore:Aggregation","provider":{"@id":"http://dp.la/api/contributor/hathitrust","name":"HathiTrust"},"object":"https://books.google.com/books/content?id=b2RUAAAAYAAJ\\u0026printsec=frontcover\\u0026img=1\\u0026zoom=5","ingestionSequence":27,"id":"ac774bfe366f0d3794a96bced3c9f664","ingestDate":"2016-09-09T16:22:07.603465Z","_rev":"12-278b6e2b378e477de56cd41b13c923d0","aggregatedCHO":"#sourceResource","_id":"hathitrust--009232885","sourceResource":{"subject":[{"name":"Domestic animals--Parasites"}],"rights":"Public domain. Learn more at http://www.hathitrust.org/access_use","format":["Electronic resource","Language material"],"date":{"displayDate":"1937]","end":"1937","begin":"1937"},"type":"text","publisher":["[Pittsburgh, Pa., Gulf Oil Corporation, Gulf Refining Company"],"specType":["Book"],"creator":["Simanton, W. A"],"title":["External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats"],"extent":["19, [15] p. 24 cm."],"@id":"http://dp.la/api/items/ac774bfe366f0d3794a96bced3c9f664#sourceResource","language":[{"iso639_3":"eng","name":"English"}],"identifier":["sdr-coo1136624","(OCoLC)41189100","Hathi: 009232885"]},"admin":{"validation_message":null,"object_status":1,"sourceResource":{"title":"External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats"},"valid_after_enrich":true},"@id":"http://dp.la/api/items/ac774bfe366f0d3794a96bced3c9f664","ingestType":"item","originalRecord":{"provider":{"@id":"http://dp.la/api/contributor/hathitrust","name":"HathiTrust"},"_id":"009232885","controlfield":[{"tag":"001","#text":"009232885"},{"tag":"003","#text":"MiAaHDL"},{"tag":"005","#text":"20101116000000.0"},{"tag":"006","#text":"m d"},{"tag":"007","#text":"cr bn ---auaua"},{"tag":"008","#text":"860819s1937 paua 000 0 eng d"}],"datafield":[{"tag":"035","ind2":"","ind1":"","subfield":{"#text":"sdr-coo1136624","code":"a"}},{"tag":"035","ind2":"","ind1":"","subfield":{"#text":"(OCoLC)41189100","code":"a"}},{"tag":"040","ind2":"","ind1":"","subfield":[{"#text":"NIC","code":"a"},{"#text":"NIC","code":"c"}]},{"tag":"100","ind2":"","ind1":"1","subfield":{"#text":"Simanton, W. A.","code":"a"}},{"tag":"245","ind2":"0","ind1":"1","subfield":{"#text":"External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats.","code":"a"}},{"tag":"260","ind2":"","ind1":"","subfield":[{"#text":"[Pittsburgh, Pa., Gulf Oil Corporation, Gulf Refining Company,","code":"a"},{"#text":"1937]","code":"c"}]},{"tag":"300","ind2":"","ind1":"","subfield":[{"#text":"19, [15] p.","code":"a"},{"#text":"illus.","code":"b"},{"#text":"24 cm.","code":"c"}]},{"tag":"490","ind2":"","ind1":"0","subfield":[{"#text":"Farm and ranch bulletin,","code":"a"},{"#text":"no. 1","code":"v"}]},{"tag":"538","ind2":"","ind1":"","subfield":{"#text":"Mode of access: Internet.","code":"a"}},{"tag":"650","ind2":"0","ind1":"","subfield":[{"#text":"Domestic animals","code":"a"},{"#text":"Parasites","code":"x"}]},{"tag":"970","ind2":"","ind1":"","subfield":{"#text":"BK","code":"a"}},{"tag":"974","ind2":"","ind1":"","subfield":[{"#text":"COO","code":"b"},{"#text":"COO","code":"c"},{"#text":"20160706","code":"d"},{"#text":"google","code":"s"},{"#text":"coo.31924002903932","code":"u"},{"#text":"1937","code":"y"},{"#text":"pd","code":"r"},{"#text":"ren","code":"q"}]}],"leader":"00623cam a22001811 4500"},"score":3.7377992},{"@context":"http://dp.la/api/items/context","isShownAt":"http://www.biodiversitylibrary.org/item/177551","dataProvider":"University of Southampton (archive.org)","@type":"ore:Aggregation","provider":{"@id":"http://dp.la/api/contributor/bhl","name":"Biodiversity Heritage Library"},"ingestionSequence":13,"id":"39ee3f5356a95eeba1fe029434fec08e","_rev":"1-3ddfdd77b65610e57d2bc134debd11fe","ingestDate":"2015-04-09T02:48:3 ...

# %% [markdown]
# By default, DPLA returns 10 items at a time. We can see from the count value, our query has 29 results. DPLA does give us a paramter we can set to change this to get up to 500 items at a time.

# %%
params = {'api_key' : key['api_key'], 'q' : 'goats+AND+cats', 'page_size': 500}
r = requests.get(url, params=params)
print(r.content)
# Out:
# b'{"count":29,"start":0,"limit":500,"docs":[{"@context":"http://dp.la/api/items/context","isShownAt":"http://catalog.hathitrust.org/Record/009232885","dataProvider":["Cornell University"],"@type":"ore:Aggregation","provider":{"@id":"http://dp.la/api/contributor/hathitrust","name":"HathiTrust"},"object":"https://books.google.com/books/content?id=b2RUAAAAYAAJ\\u0026printsec=frontcover\\u0026img=1\\u0026zoom=5","ingestionSequence":27,"id":"ac774bfe366f0d3794a96bced3c9f664","ingestDate":"2016-09-09T16:22:07.603465Z","_rev":"12-278b6e2b378e477de56cd41b13c923d0","aggregatedCHO":"#sourceResource","_id":"hathitrust--009232885","sourceResource":{"subject":[{"name":"Domestic animals--Parasites"}],"rights":"Public domain. Learn more at http://www.hathitrust.org/access_use","format":["Electronic resource","Language material"],"date":{"displayDate":"1937]","end":"1937","begin":"1937"},"type":"text","publisher":["[Pittsburgh, Pa., Gulf Oil Corporation, Gulf Refining Company"],"specType":["Book"],"creator":["Simanton, W. A"],"title":["External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats"],"extent":["19, [15] p. 24 cm."],"@id":"http://dp.la/api/items/ac774bfe366f0d3794a96bced3c9f664#sourceResource","language":[{"iso639_3":"eng","name":"English"}],"identifier":["sdr-coo1136624","(OCoLC)41189100","Hathi: 009232885"]},"admin":{"validation_message":null,"object_status":1,"sourceResource":{"title":"External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats"},"valid_after_enrich":true},"@id":"http://dp.la/api/items/ac774bfe366f0d3794a96bced3c9f664","ingestType":"item","originalRecord":{"provider":{"@id":"http://dp.la/api/contributor/hathitrust","name":"HathiTrust"},"_id":"009232885","controlfield":[{"tag":"001","#text":"009232885"},{"tag":"003","#text":"MiAaHDL"},{"tag":"005","#text":"20101116000000.0"},{"tag":"006","#text":"m d"},{"tag":"007","#text":"cr bn ---auaua"},{"tag":"008","#text":"860819s1937 paua 000 0 eng d"}],"datafield":[{"tag":"035","ind2":"","ind1":"","subfield":{"#text":"sdr-coo1136624","code":"a"}},{"tag":"035","ind2":"","ind1":"","subfield":{"#text":"(OCoLC)41189100","code":"a"}},{"tag":"040","ind2":"","ind1":"","subfield":[{"#text":"NIC","code":"a"},{"#text":"NIC","code":"c"}]},{"tag":"100","ind2":"","ind1":"1","subfield":{"#text":"Simanton, W. A.","code":"a"}},{"tag":"245","ind2":"0","ind1":"1","subfield":{"#text":"External parasites that attack cattle, sheep, goats, horses, mules, hogs, dogs and cats.","code":"a"}},{"tag":"260","ind2":"","ind1":"","subfield":[{"#text":"[Pittsburgh, Pa., Gulf Oil Corporation, Gulf Refining Company,","code":"a"},{"#text":"1937]","code":"c"}]},{"tag":"300","ind2":"","ind1":"","subfield":[{"#text":"19, [15] p.","code":"a"},{"#text":"illus.","code":"b"},{"#text":"24 cm.","code":"c"}]},{"tag":"490","ind2":"","ind1":"0","subfield":[{"#text":"Farm and ranch bulletin,","code":"a"},{"#text":"no. 1","code":"v"}]},{"tag":"538","ind2":"","ind1":"","subfield":{"#text":"Mode of access: Internet.","code":"a"}},{"tag":"650","ind2":"0","ind1":"","subfield":[{"#text":"Domestic animals","code":"a"},{"#text":"Parasites","code":"x"}]},{"tag":"970","ind2":"","ind1":"","subfield":{"#text":"BK","code":"a"}},{"tag":"974","ind2":"","ind1":"","subfield":[{"#text":"COO","code":"b"},{"#text":"COO","code":"c"},{"#text":"20160706","code":"d"},{"#text":"google","code":"s"},{"#text":"coo.31924002903932","code":"u"},{"#text":"1937","code":"y"},{"#text":"pd","code":"r"},{"#text":"ren","code":"q"}]}],"leader":"00623cam a22001811 4500"},"score":3.7377992},{"@context":"http://dp.la/api/items/context","isShownAt":"http://www.biodiversitylibrary.org/item/177551","dataProvider":"University of Southampton (archive.org)","@type":"ore:Aggregation","provider":{"@id":"http://dp.la/api/contributor/bhl","name":"Biodiversity Heritage Library"},"ingestionSequence":13,"id":"39ee3f5356a95eeba1fe029434fec08e","_rev":"1-3ddfdd77b65610e57d2bc134debd11fe","ingestDate":"2015-04-09T02:48: ...

# %% [markdown]
# If we were working with an API that limited us to only 10 items at a time, we could write a loop to pull our data.
#
# The file "seeclickfix_api.py" in the api folder of this repo is an example of how you can pull multiple pages of data from an API.

# %% [markdown]
# ## Scraping

# %% [markdown]
# In the API section, we used urllib to call and API and save data. We can also use it to download webpages.

# %%
html = urllib.request.urlopen("http://xkcd.com/1481/")
print(html.read())
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/b0dcca.css" title="Default"/>\n<title>xkcd: API</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<script>\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\n(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),\nm=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)\n})(window,document,\'script\',\'//www.google-analytics.com/analytics.js\',\'ga\');\n\nga(\'create\', \'UA-25700708-7\', \'auto\');\nga(\'send\', \'pageview\');\n</script>\n<script type="text/javascript" src="//xkcd.com/1350/jquery.min.js"></script>\n<script type="text/javascript" src="//xkcd.com/static/json2.js"></script>\n\n</head>\n<body>\n<div id="topContainer">\n<div id="topLeft">\n<ul>\n<li><a href="/archive">Archive</a></li>\n<li><a href="http://what-if.xkcd.com">What If?</a></li>\n<li><a href="http://blag.xkcd.com">Blag</a></li>\n<li><a href="http://store.xkcd.com/">Store</a></li>\n<li><a rel="author" href="/about">About</a></li>\n</ul>\n</div>\n<div id="topRight">\n<div id="masthead">\n<span><a href="/"><img src="//imgs.xkcd.com/static/terrible_small_logo.png" alt="xkcd.com logo" height="83" width="185"/></a></span>\n<span id="slogan">A webcomic of romance,<br/> sarcasm, math, and language.</span>\n</div>\n<div id="news">\n      <script>\n         xmlhttp = window.XDomainRequest ? new XDomainRequest() : new XMLHttpRequest()\n        xmlhttp.onreadystatechange=function() {\n         if (xmlhttp.readyState==4 && xmlhttp.status==200) {\n          var newdiv = document.createElement("div")\n          newdiv.innerHTML = xmlhttp.responseText\n          document.getElementById("news").appendChild(newdiv)\n         }\n        }\n        xmlhttp.open("GET","//c.xkcd.com/thing-explainer/news",true)\n        xmlhttp.send()\n      </script>\n<script>\nmu = window.location.href.split("#")[1]\nif(/([0-9a-b]+-)[4][0-9a-b]+/.test(mu)) { window.location.href = "http://xkcd.com/1663/#"+mu }\n</script>\n\n\n</div>\n</div>\n<div id="bgLeft" class="bg box"></div>\n<div id="bgRight" class="bg box"></div>\n</div>\n<div id="middleContainer" class="box">\n\n<div id="ctitle">API</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/1480/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="/1482/" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<div id="comic">\n<img src="//imgs.xkcd.com/comics/api.png" title="ACCESS LIMITS: Clients may maintain connections to the server for no more than 86,400 seconds per day. If you need additional time, you may contact IERS to file a request for up to one additional second." alt="API" srcset="//imgs.xkcd.com/comics/api_2x.png 2x"/>\n</div>\n<ul class="comicNav">\n<li><a href="/1/">|&lt;</a></li>\n<li><a rel="prev" href="/1480/" accesskey="p">&lt; Prev</a></li>\n<li><a href="//c.xkcd.com/random/comic/">Random</a></li>\n<li><a rel="next" href="/1482/" accesskey="n">Next &gt;</a></li>\n<li><a href="/">&gt;|</a></li>\n</ul>\n<br />\nPermanent link to this comic: http://xkcd.com/1481/<br />\nImage URL (for hotlinking/embedding): http://imgs.xkcd.com/comics/api.png\n<div id="transcript" style="display: none">((This is a faux-screenshot of a technical document))\n[[A figure sits at a computer upon a desk, apparently engrossed in the document which we now see before us.]]\nTITLE: API GUIDE\nRequest URL Format: domain\nuser\nitem\nServer will return an XML document which contains the requested data and documentation describing how the data is organized spatiall ...

# %% [markdown]
# We can use the urlretrieve function to retrieve a specific resources, such as a file, via url. This is basic web scraping.
#
# If we look through our html above, we can see there is a url for the image in the page.

# %%
urllib.request.urlretrieve("http://imgs.xkcd.com/comics/api.png", "api.png")
# Out:
# ('api.png', <http.client.HTTPMessage at 0x10b3c8b00>)

# %% [markdown]
# The cell below this is markdown. Double-click on it so it is in editing mode, then execute it to display the file you downloaded with the previous command.

# %% [markdown]
# ![](api.png)

# %% [markdown]
# Using these methods, we are treating the html as an unstructured string. If we want to retrieve the structured markup, we can use [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/). "Beautiful Soup is a Python library for pulling data out of HTML and XML files. It works with your favorite parser to provide idiomatic ways of navigating, searching, and modifying the parse tree. It commonly saves programmers hours or days of work."

# %%
from bs4 import BeautifulSoup
url = 'https://litemind.com/best-famous-quotes'

html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html,"html.parser")
for quote in soup.findAll('div',{'class':'wp_quotepage'}):
    text = quote.findChildren()[0].renderContents()
    author = quote.findChildren()[1].renderContents()
    print(text, author)
# Out:
# b'1. You can do anything, but not everything.' b'\xe2\x80\x94David Allen'
# b'2. Perfection is achieved, not when there is nothing more to add, but when there is nothing left to take away.' b'\xe2\x80\x94Antoine de Saint-Exup\xc3\xa9ry'
# b'3. The richest man is not he who has the most, but he who needs the least.' b'\xe2\x80\x94Unknown Author'
# b'4. You miss 100 percent of the shots you never take.' b'\xe2\x80\x94Wayne Gretzky'
# b'5. Courage is not the absence of fear, but rather the judgement that something else is more important than fear.' b'\xe2\x80\x94Ambrose Redmoon'
# b'6. You must be the change you wish to see in the world.' b'\xe2\x80\x94Gandhi'
# b'7. When hungry, eat your rice; when tired, close your eyes. Fools may laugh at me, but wise men will know what I mean.' b'\xe2\x80\x94Lin-Chi'
# b'8. The third-rate mind is only happy when it is thinking with the majority. The second-rate mind is only happy when it is thinking with the minority. The first-rate mind is only happy when it is thinking.' b'\xe2\x80\x94A. A. Milne'
# b'9. To the man who only has a hammer, everything he encounters begins to look like a nail.' b'\xe2\x80\x94Abraham Maslow'
# b'10. We are what we repeatedly do; excellence, then, is not an act but a habit.' b'\xe2\x80\x94Aristotle'
# b'11. A wise man gets more use from his enemies than a fool from his friends.' b'\xe2\x80\x94Baltasar Gracian'
# b'12. Do not seek to follow in the footsteps of the men of old; seek what they sought.' b'\xe2\x80\x94Basho'
# b'13. Watch your thoughts; they become words.<br/>Watch your words; they become actions.<br/>Watch your actions; they become habits.<br/>Watch your habits; they become character.<br/>Watch your character; it becomes your destiny.' b''
# b'14. Everyone is a genius at least once a year. The real geniuses simply have their bright ideas closer together.' b'\xe2\x80\x94Georg Christoph Lichtenberg'
# b'15. What we think, or what we know, or what we believe is, in the end, of little consequence. The only consequence is what we do.' b'\xe2\x80\x94John Ruskin'
# b'16. The real voyage of discovery consists not in seeking new lands but seeing with new eyes.' b'\xe2\x80\x94Marcel Proust'
# b'17. Work like you don\xe2\x80\x99t need money, love like you\xe2\x80\x99ve never been hurt, and dance like no one\xe2\x80\x99s watching' b'\xe2\x80\x94Unknown Author'
# b'18. Try a thing you haven\xe2\x80\x99t done three times. Once, to get over the fear of doing it. Twice, to learn how to do it. And a third time, to figure out whether you like it or not.' b'\xe2\x80\x94Virgil Garnett Thomson'
# b'19. Even if you\xe2\x80\x99re on the right track, you\xe2\x80\x99ll get run over if you just sit there.' b'\xe2\x80\x94Will Rogers'
# b'20. People often say that motivation doesn\xe2\x80\x99t last. Well, neither does bathing \xe2\x80\x93 that\xe2\x80\x99s why we recommend it daily.' b'\xe2\x80\x94Zig Ziglar'
# b'21. Before I got married I had six theories about bringing up children; now I have six children and no theories.' b'\xe2\x80\x94John Wilmot'
# b'22. What the world needs is more geniuses with humility, there are so few of us left.' b'\xe2\x80\x94Oscar Levant'
# b'23. Always forgive your enemies; nothing annoys them so much.' b'\xe2\x80\x94Oscar Wilde'
# b'24. I\xe2\x80\x99ve gone into hundreds of [fortune-teller\xe2\x80\x99s parlors], and have been told thousands of things, but nobody ever told me I was a policewoman getting ready to arrest her.' b'\xe2\x80\x94New York City detective'
# b'25. When you go into court you are putting your fate into the hands of twelve people who weren\xe2\x80\x99t smart enough to get out of jury duty.' b'\xe2\x80\x94Norm Crosby'
# b'26. Those who believe in telekinetics, raise my hand.' b'\xe2\x80\x94Kurt Vonnegut'
# b'27. Just the fact that some geniuses were laughed at does not imply that all who are laughed at are geniuses. They laughed at Columbus, they laughed at Fulton, they laughed at the Wright brothers. But they also laughed at Bozo the Clown.' b'\xe2\x80\x94Carl Sagan'
# b'28. My pessimism extends to the point of even suspecting the sincerity of the pessimists.' b'\xe2\x80\x94Jean Rostand'
# b'29. Sometimes I worry about being a success in a mediocre world.' b'\xe2\x80\x94Lily Tomlin'
# b'30. I quit therapy because my analyst was trying to help me behind my back.' b'\xe2\x80\x94Richard Lewis'
# b'31. We\xe2\x80\x99ve heard that a million monkeys at a million keyboards could produce the complete works of Shakespeare; now, thanks to the Internet, we know that is not true.' b'\xe2\x80\x94Robert Wilensky'
# b'32. If there are no stupid questions, then what kind of questions do stupid people ask? Do they get smart just in time to ask questions?' b'\xe2\x80\x94Scott Adams'
# b'33. If the lessons of history teach us anything it is that nobody learns the lessons that history teaches us.' b'\xe2\x80\x94Anon'
# b'34. When I was a boy I was told that anybody could become President. Now I\xe2\x80\x99m beginning to believe it.' b'\xe2\x80\x94Clarence Darrow'
# b'35. Laughing at our mistakes can lengthen our own life. Laughing at someone else\xe2\x80\x99s can shorten it.' b'\xe2\x80\x94Cullen Hightower'
# b'36. There are many who dare not kill themselves for fear of what the neighbors will say.' b'\xe2\x80\x94Cyril Connolly'
# b'37. There\xe2\x80\x99s so much comedy on television. Does that cause comedy in the streets?' b'\xe2\x80\x94Dick Cavett'
# b'38. All men are frauds. The only difference between them is that some admit it. I myself deny it.' b'\xe2\x80\x94H. L. Mencken'
# b'39. I don\xe2\x80\x99t mind what Congress does, as long as they don\xe2\x80\x99t do it in the streets and frighten the horses.' b'\xe2\x80\x94Victor Hugo'
# b'40. I took a speed reading course and read \xe2\x80\x98War and Peace\xe2\x80\x99 in twenty minutes. It involves Russia.' b'\xe2\x80\x94Woody Allen'
# b'41. The person who reads too much and uses his brain too little will fall into lazy habits of thinking.' b'\xe2\x80\x94Albert Einstein'
# b'42. Believe those who are seeking the truth. Doubt those who find it.' b'\xe2\x80\x94Andr\xc3\xa9 Gide'
# b'43. It is the mark of an educated mind to be able to entertain a thought without accepting it.' b'\xe2\x80\x94Aristotle'
# b'44. I\xe2\x80\x99d rather live with a good question than a bad answer.' b'\xe2\x80\x94Aryeh Frimer'
# b'45. We learn something every day, and lots of times it\xe2\x80\x99s that what we learned the day before was wrong.' b'\xe2\x80\x94Bill Vaughan'
# b'46. I have made this letter longer than usual because I lack the time to make it shorter.' b'\xe2\x80\x94Blaise Pascal'
# b'47. Don\xe2\x80\x99t ever wrestle with a pig. You\xe2\x80\x99ll both get dirty, but the pig will enjoy it.' b'\xe2\x80\x94Cale Yarborough'
# b'48. An inventor is simply a fellow who doesn\xe2\x80\x99t take his education too seriously.' b'\xe2\x80\x94Charles F. Kettering'
# b'49. Asking a working writer what he thinks about critics is like asking a lamppost how it feels about dogs.' b'\xe2\x80\x94Christopher Hampton'
# b'50. Better to write for yourself and have no public, than to write for the public and have no self.' b'\xe2\x80\x94Cyril Connolly'
# b'51. Never be afraid to laugh at yourself, after all, you could be missing out on the joke of the century.' b'\xe2\x80\x94Dame Edna Everage'
# b'52. I am patient with stupidity but not with those who are proud of it.' b'\xe2\x80\x94Edith Sitwell'
# b'53. Normal is getting dressed in clothes that you buy for work and driving through traffic in a car that you are still paying for \xe2\x80\x93 in order to get to the job you need to pay for the clothes and the car, and the house you leave vacant all day so you can afford to live in it.' b'\xe2\x80\x94Ellen Goodman'
# b'54. The cure for boredom is curiosity. There is no cure for curiosity.' b'\xe2\x80\x94Ellen Parr'
# b'55. Advice is what we ask for when we already know the answer but wish we didn\xe2\x80\x99t.' b'\xe2\x80\x94Erica Jong'
# b'56. Some people like my advice so much that they frame it upon the wall instead of using it.' b'\xe2\x80\x94Gordon R. Dickson'
# b'57. The trouble with the rat race is that even if you win, you\xe2\x80\x99re still a rat.' b'\xe2\x80\x94Lily Tomlin'
# b'58. Never ascribe to malice, that which can be explained by incompetence.' b'\xe2\x80\x94Napoleon (Hanlon\xe2\x80\x99s Razor)'
# b'59. Imagination was given to man to compensate him for what he is not, and a sense of humor was provided to console him for what he is.' b'\xe2\x80\x94Oscar Wilde'
# b'60. When a person can no longer laugh at himself, it is time for others to laugh at him.' b'\xe2\x80\x94Thomas Szasz'

# %% [markdown]
# Scraping takes work. You need to be able to read the page source to understand how the information is structured and how you can access it. The examples here have been fairly straightforward. Sometimes the markup is messy and poorly formed.
#
# The next commands will look at a [restaurant inspection report](http://dc.healthinspections.us/webadmin/dhd_431/lib/mod/inspection/paper/_paper_food_inspection_report.cfm?inspectionID=105185&wguid=1367&wgunm=sysact&wgdmn=431) from the DC Department of Health.
#
# The markup is messy. It took me a while to parse the data I wanted from it. And once I did, I spent a while cleaning it up too.

# %%
# pull in the html and take a look at it
html_file = "http://dc.healthinspections.us/webadmin/dhd_431/lib/mod/inspection/paper/_paper_food_inspection_report.cfm?inspectionID=105185&wguid=1367&wgunm=sysact&wgdmn=431"
html_rpt = urllib.request.urlopen(html_file).read()
html_rpt
# Out:
# b'\r\n<!DOCTYPE html>\r\n<html>\r\n\r\n<head>\r\n<title>Food Establishment Inspection Report</title>\r\n<link href="http://dc.healthinspections.us:80/webadmin/dhd_431/lib/mod/inspection/paper/css/generic.css" rel="stylesheet" type="text/css" media="all, screen, print" />\r\n<style type="text/css">\r\ndiv.container {\r\n\tborder-bottom: 1px solid black;\r\n\tmargin-right:15px;\r\n  }\r\ndiv.container span {\r\n\tposition:relative;\r\n\tbottom:-2px;\r\n\tbackground:#FFFFFF;\r\n  }\r\n.checkboxRedN {\r\nfloat:left;\r\nborder:1px solid red;\r\nwidth:10px;\r\nheight:10px;\r\nfont-size:5px;\r\n}\r\n.checkboxN {\r\nborder:1px solid black;\r\nwidth:10px;\r\nheight:10px;\r\nfont-size:2px;\r\n}\r\n.boxwid2{\r\n\twidth:185px;\r\n}\r\n.spacer{\r\n\twidth:10px;\r\n}\r\n.line1{\r\n\twidth:400px;\r\n}\r\n.line2{\r\n\twidth:230px;\r\n}\r\n.line3{\r\n\twidth:245px;\r\n}\r\n.line5{\r\n\twidth:235px;\r\n}\r\n.hdrSpace{\r\n\twidth: 4px;\r\n}\r\n.hdrSpace2{\r\n\twidth: 4px;\r\n}\r\n.inspTypeSpace{\r\n\twidth: 15px;\r\n}\r\n.vioHeight {\r\n\t\theight: 675px;\r\n}\r\n.sigWidth {\r\n\twidth: 750px;\r\n}\r\n.blankFld {\r\n\tborder-bottom: 1px solid black;\r\n\tdisplay:inline-block;\r\n}\r\n@media print{\r\n\tbody {\r\n\t\tmargin-top:inherit;\r\n\t\tmargin-left:inherit;\r\n\t\tmargin-right:inherit;\r\n\t\tmargin-bottom:inherit;\r\n\t\tfont-size:inherit;\r\n\t\tfont-family:inherit;\r\n\t\twidth:inherit;\r\n\t\theight:inherit;\r\n\t}\r\n\t.sigWidth {\r\n\t\twidth: 755px;\r\n\t}\r\n\t.vioHeight {\r\n\t\theight: 565px;\r\n\t}\r\n\t.boxwid2{\r\n\t\twidth:215px;\r\n\t}\r\n\t.spacer{\r\n\t\twidth:25px;\r\n\t}\r\n\t.line1{\r\n\t\twidth:421px;\r\n\t}\r\n\t.line2{\r\n\t\twidth:248px;\r\n\t}\r\n\t.line3{\r\n\t\twidth:265px;\r\n\t}\r\n\t.line5{\r\n\t\twidth:255px;\r\n\t}\r\n\t.hdrSpace{\r\n\t\twidth: 4px;\r\n\t}\r\n\t.hdrSpace2{\r\n\t\twidth: 4px;\r\n\t}\r\n\t.inspTypeSpace{\r\n\t\twidth: 23px;\r\n\t}\r\n}\r\n</style>\r\n</head>\r\n<body class="pt10 arial" style="margin-left:0px;margin-right:0px;margin-top:0px;margin-bottom:0px;width:750px;">\r\n\r\n\r\n\r\n\t<table cellpadding="0" cellspacing="0" style="width:750px;margin-bottom:5px;margin-top:10px;">\r\n        <tr>\r\n            <td style="vertical-align:bottom;width:110px;">\r\n                \r\n                    <img src="http://dc.healthinspections.us:80/webadmin/dhd_431/lib/mod/inspection/paper/images/new_bars_and_stars_blueText.jpg" alt="image" width="150" height="40" />\r\n                \r\n            </td>\r\n            <td class="center" style="vertical-align:middle;width:530px;">\r\n                <span class="times strong" style="font-size:16pt;">Food Establishment Inspection Report</span><br/>\r\n                <span class="pt8">Pursuant to Title 25-A of the District of Columbia Municipal Regulations</span>\r\n            </td>\r\n            <td style="vertical-align:bottom;text-align:right;width:110px;">\r\n                <img src="http://dc.healthinspections.us:80/webadmin/dhd_431/lib/mod/inspection/paper/images/doh_logo.jpg" alt="image" width="75" height="30" />\r\n            </td>\r\n        </tr>\r\n    </table>\r\n\t\r\n    \r\n\t\r\n    <div class="border times center" style="font-size:7.5pt;">\r\n \t   <em>Bureau of Community Hygiene <span class="hdrSpace" style="display: inline-block;">&nbsp;</span>&bull;<span class="hdrSpace" style="display: inline-block;">&nbsp;</span> Food Safety &amp; Hygiene Inspection Services Division <span class="hdrSpace" style="display: inline-block;" >&nbsp;</span>&bull;<span class="hdrSpace" style="display: inline-block;">&nbsp;</span> 899 North Capitol Street, NE-8<sup>th</sup> Floor <span class="hdrSpace" style="display: inline-block;">&nbsp;</span>&bull;<span class="hdrSpace" style="display: inline-block;">&nbsp;</span> Washington, DC 20002 <span class="hdrSpace" style="display: inline-block;">&nbsp;</span>&bull;<span class="hdrSpace" style="display: inline-block;">&nbsp;</span>food.safety@dc.gov</em>\r\n    </div>\r\n    \r\n\t\r\n\t<table class ...

# %%
# Using Beautiful Soup involved a lot of trial and error. Here are some examples of what I parsed.
soup = BeautifulSoup(html_rpt, 'html.parser')
inspection = soup.find_all('tr')

# %%
# phone number
inspection[5].get_text()
# Out:
# '\n\n\nTelephone\n\xa0(202) 667-0010\n\xa0E-mail address\r\n\t\t\t\t\t\t\t\t\xa0kelvin.ferrufino@gmail.com\r\n\t\t\t\t\t\t\t\n\n'

# %%
# inspection details
inspection[6].get_text()
# Out:
# '\n\n\nDate of Inspection\n\xa006\n/\n\xa026\n/\n\xa02013\n\xa0\xa0\xa0\xa0Time In\n\xa007\n:\n\xa000\nPM\n\xa0\xa0\xa0\xa0Time Out\n\xa008\n:\n\xa015\nAM\n\xa0\n\n\n'

# %%
# the inspector name and badge number
tables = soup.find_all('table')
inspector_info = tables[11]
inspector = inspector_info.find_all("td")

print(inspector[1])
print(inspector[2])
# Out:
# <td style="width:225px; vertical-align: bottom;"> A. Jackson</td>
# <td style="width:90px; vertical-align: bottom;">54 </td>

# %% [markdown]
# There are a lot of resources out there for building scrapers. Take a look at the resources in the slides. And try out this tutorial for [building your first scraper](http://first-web-scraper.readthedocs.io/en/latest/).
#
# Thanks!
